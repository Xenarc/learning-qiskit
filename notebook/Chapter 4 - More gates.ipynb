# %%
from qiskit import QuantumCircuit, assemble, Aer
from math import pi, sqrt
from qiskit.visualization import plot_bloch_multivector, plot_histogram
sim = Aer.get_backend('aer_simulator')

# %%
qc = QuantumCircuit(1)
qc.p(pi/4, 0)
qc.draw(output='mpl')

# %%
qc = QuantumCircuit(1)
qc.s(0)   # Apply S-gate to qubit 0
qc.sdg(0) # Apply Sdg-gate to qubit 0
qc.draw(output='mpl')

# %% [markdown]
# The above gate is equivilent to the identity matrix, and will have no effect on a qubit.

# %% [markdown]
# ![image.png](attachment:66d05879-ca52-43f9-a441-aacbb31668e5.png)

# %% [markdown]
# ![image.png](attachment:db6130e6-5821-44ce-b53f-3a2c99ea6f69.png)

# %% [markdown]
# https://raw.githubusercontent.com/qiskit-community/qiskit-textbook/main/content/ch-states/supplements/single-gates-cheatsheet.pdf
